# %%
# %%capture
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.utils.data as dt
import pickle as cPickle
import gzip
import cv2
from PIL import Image

MODEL_STORE_PATH = "/media/khurshed2504/Data/PycharmProjects/ML_temp0/PyTorch Models/MNIST 0"

num_epochs = 5
num_classes = 10
batch_size = 128
learning_rate = 0.001

DATA_PATH = "/media/khurshed2504/Data/PycharmProjects/ML_temp0"

trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root=DATA_PATH, train=True, transform=trans, download=True)
test_dataset = torchvision.datasets.MNIST(root=DATA_PATH, train=False, transform=trans)


train_loader = dt.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = dt.DataLoader(dataset=test_dataset, shuffle=False)


class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet,self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1,32, 5, 1, padding = 2),
            torch.nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, 5, 1, padding=2),
            torch.nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )

        self.dropout = nn.Dropout()

        self.fc1 = nn.Linear(7*7*64, 1000)
        self.fc2 = nn.Linear(1000, 10)


    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        # print(out.shape)
        out = out.reshape((-1,64*7*7))
        # print(out.shape)
        out = self.dropout(out)
        out = self.fc1(out)
        out = self.fc2(out)

        return out

modeltest = ConvNet()
modeltest.load_state_dict(torch.load(MODEL_STORE_PATH))
modeltest.eval()

# %%
pil_image = Image.open('0(0).jpg')
img = cv2.imread('0(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  0

# %%
pil_image = Image.open('1(0).jpg')
img = cv2.imread('1(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  1

# %%
pil_image = Image.open('2(0).jpg')
img = cv2.imread('2(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  2

# %%
pil_image = Image.open('3(0).jpg')
img = cv2.imread('3(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  3

# %%
pil_image = Image.open('4(0).jpg')
img = cv2.imread('4(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  4

# %%
pil_image = Image.open('5(0).jpg')
img = cv2.imread('5(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  5

# %%
pil_image = Image.open('6(0).jpg')
img = cv2.imread('6(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  6

# %%
pil_image = Image.open('7(0).jpg')
img = cv2.imread('7(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  7

# %%
pil_image = Image.open('8(0).jpg')
img = cv2.imread('8(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  8

# %%
pil_image = Image.open('9(0).jpg')
img = cv2.imread('9(0).jpg',1)
img = cv2.resize(img,(28,28))
gray = 255 - cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(pil_image)

x = gray
x = np.float32(x/255)

x = torch.from_numpy(x)
x = x.type(torch.float32)
x = x.reshape(1,1,28,28)
outputs_test = modeltest(x)

_, predicted = torch.max(outputs_test, 1)

print("I think its a : ", predicted.item())
# Out:
# I think its a :  9
